# %% [markdown]
# ## 1- Installation

# %%
pip install gymnasium[box2d] stable_baselines3[extra]
# Out:
# Requirement already satisfied: gymnasium[box2d] in c:\users\afroukh\anaconda\lib\site-packages (0.29.1)
# Requirement already satisfied: stable_baselines3[extra] in c:\users\afroukh\anaconda\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\afroukh\anaconda\lib\site-packages (from gymnasium[box2d]) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\afroukh\anaconda\lib\site-packages (from gymnasium[box2d]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\afroukh\anaconda\lib\site-packages (from gymnasium[box2d]) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\afroukh\anaconda\lib\site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in c:\users\afroukh\anaconda\lib\site-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\afroukh\anaconda\lib\site-packages (from gymnasium[box2d]) (2.5.2)
# Requirement already satisfied: swig==4.* in c:\users\afroukh\anaconda\lib\site-packages (from gymnasium[box2d]) (4.2.1)
# Requirement already satisfied: torch>=1.13 in c:\users\afroukh\anaconda\lib\site-packages (from stable_baselines3[extra]) (2.2.2)
# Requirement already satisfied: pandas in c:\users\afroukh\anaconda\lib\site-packages (from stable_baselines3[extra]) (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\afroukh\anaconda\lib\site-packages (from stable_baselines3[extra]) (3.7.2)
# Collecting opencv-python (from stable_baselines3[extra])
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/c7/ec/9dabb6a9abfdebb3c45b0cc52dec901caafef2b2c7e7d6a839ed86d81e91/opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\afroukh\anaconda\lib\site-packages (from stable_baselines3[extra]) (2.16.2)
# Requirement already satisfied: psutil in c:\users\afroukh\appdata\roaming\python\python311\site-packages (from stable_baselines3[extra]) (5.9.7)
# Requirement already satisfied: tqdm in c:\users\afroukh\anaconda\lib\site-packages (from stable_baselines3[extra]) (4.65.0)
# Requirement already satisfied: rich in c:\users\afroukh\anaconda\lib\site-packages (from stable_baselines3[extra]) (13.7.1)
# Collecting shimmy[atari]~=1.3.0 (from stable_baselines3[extra])
#   Obtaining dependency information for shimmy[atari]~=1.3.0 from https://files.pythonhosted.org/packages/dc/f9/07ef16463db14ac1b30f149c379760f5cacf3fc677b295d29a92f3127914/Shimmy-1.3.0-py3-none-any.whl.metadata
#   Using cached Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in c:\users\afroukh\anaconda\lib\site-packages (from stable_baselines3[extra]) (9.4.0)
# Collecting autorom[accept-rom-license]~=0.6.1 (from stable_baselines3[extra])
#   Obtaining dependency information for autorom[accept-rom-license]~=0.6.1 from https://files.pythonhosted.org/packages/02/e1/90b168a5dbc89a4e9b2206a99238f3ea3fc281052bb2dc236d4aa15e5e87/AutoROM-0.6.1-py3-none-any.whl.metadata
#   Using cached AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in c:\users\afroukh\anaconda\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra]) (8.0.4)
# Requirement already satisfied: requests in c:\users\afroukh\anaconda\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra]) (2.31.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra])
#   Using cached AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.3.0->stable_baselines3[extra])
#   Obtaining dependency information for ale-py~=0.8.1 from https://files.pythonhosted.org/packages/b2/a5/f93747205056eb741d1a34acb34b69ea0a46ef9eee4699e0a1cb67628646/ale_py-0.8.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached ale_py-0.8.1-cp311-cp311-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: absl-py>=0.4 in c:\users\afroukh\anaconda\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\afroukh\anaconda\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (1.62.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\afroukh\anaconda\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (3.4.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\afroukh\anaconda\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\afroukh\anaconda\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (68.0.0)
# Requirement already satisfied: six>1.9 in c:\users\afroukh\anaconda\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\afroukh\anaconda\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\afroukh\anaconda\lib\site-packages (from tensorboard>=2.9.1->stable_baselines3[extra]) (2.2.3)
# Requirement already satisfied: filelock in c:\users\afroukh\anaconda\lib\site-packages (from torch>=1.13->stable_baselines3[extra]) (3.9.0)
# Requirement already satisfied: sympy in c:\users\afroukh\anaconda\lib\site-packages (from torch>=1.13->stable_baselines3[extra]) (1.11.1)
# Requirement already satisfied: networkx in c:\users\afroukh\anaconda\lib\site-packages (from torch>=1.13->stable_baselines3[extra]) (3.1)
# Requirement already satisfied: jinja2 in c:\users\afroukh\anaconda\lib\site-packages (from torch>=1.13->stable_baselines3[extra]) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\afroukh\anaconda\lib\site-packages (from torch>=1.13->stable_baselines3[extra]) (2023.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\afroukh\anaconda\lib\site-packages (from matplotlib->stable_baselines3[extra]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\afroukh\anaconda\lib\site-packages (from matplotlib->stable_baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\afroukh\anaconda\lib\site-packages (from matplotlib->stable_baselines3[extra]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\afroukh\anaconda\lib\site-packages (from matplotlib->stable_baselines3[extra]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\afroukh\anaconda\lib\site-packages (from matplotlib->stable_baselines3[extra]) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\afroukh\anaconda\lib\site-packages (from matplotlib->stable_baselines3[extra]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\afroukh\anaconda\lib\site-packages (from matplotlib->stable_baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\afroukh\anaconda\lib\site-packages (from pandas->stable_baselines3[extra]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\afroukh\anaconda\lib\site-packages (from pandas->stable_baselines3[extra]) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\afroukh\anaconda\lib\site-packages (from rich->stable_baselines3[extra]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\afroukh\anaconda\lib\site-packages (from rich->stable_baselines3[extra]) (2.15.1)
# Requirement already satisfied: colorama in c:\users\afroukh\anaconda\lib\site-packages (from tqdm->stable_baselines3[extra]) (0.4.6)
# Collecting importlib-resources (from ale-py~=0.8.1->shimmy[atari]~=1.3.0->stable_baselines3[extra])
#   Obtaining dependency information for importlib-resources from https://files.pythonhosted.org/packages/75/06/4df55e1b7b112d183f65db9503bff189e97179b256e1ea450a3c365241e0/importlib_resources-6.4.0-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\afroukh\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable_baselines3[extra]) (0.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\afroukh\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable_baselines3[extra]) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\afroukh\anaconda\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\afroukh\anaconda\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\afroukh\anaconda\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\afroukh\anaconda\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable_baselines3[extra]) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\afroukh\anaconda\lib\site-packages (from sympy->torch>=1.13->stable_baselines3[extra]) (1.3.0)
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# Using cached ale_py-0.8.1-cp311-cp311-win_amd64.whl (952 kB)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml): started
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml): finished with status 'done'
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446678 sha256=5e4ce1307dd435cfb866d13002cec8e0bad87f27abbdafe6f710c75cdad7e3f0
#   Stored in directory: c:\users\afroukh\appdata\local\pip\cache\wheels\bc\fc\c6\8aa657c0d2089982f2dabd110efc68c61eb49831fdb7397351
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: opencv-python, importlib-resources, shimmy, AutoROM.accept-rom-license, autorom, ale-py
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 importlib-resources-6.4.0 opencv-python-4.9.0.80 shimmy-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2- Importation

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# ## 3- Tester l'environnement

# %%
env = gym.make('LunarLander-v2', render_mode="human")

# %%
episodes=10
for episode in range (0,episodes+1):
    state=env.reset()
    done=False
    score=0
    while not done:
        env.render()
        action=env.action_space.sample()
        observation ,reward ,done ,truncated ,info =env.step(action)
        score+=reward;
    print("Episode : {} ,Score : {}".format(episode,score))
env.close()
# Out:
# Episode : 0 ,Score : -106.06068647208392
# Episode : 1 ,Score : -30.363187126957698
# Episode : 2 ,Score : -345.0444552209814
# Episode : 3 ,Score : -77.67371878172969
# Episode : 4 ,Score : -118.71002047618778
# Episode : 5 ,Score : -64.08999497749542
# Episode : 6 ,Score : -187.92720321285282
# Episode : 7 ,Score : -289.36140405487805
# Episode : 8 ,Score : -365.47787947578826
# Episode : 9 ,Score : -252.36384743444887
# Episode : 10 ,Score : -174.90442492027617

# %% [markdown]
# ## 4- Apprentissage par renforcement

# %%
env = gym.make('LunarLander-v2')
env = DummyVecEnv([lambda:env])

# %%
model = PPO(
    policy="MlpPolicy",
    env=env,
    n_steps=1024,
    batch_size=64,
    n_epochs=4,
    gamma=0.999,
    gae_lambda=0.98,
    ent_coef=0.01,
    verbose=1,tensorboard_log="./PPOLunar_tensorboard/"
)
model.learn(total_timesteps=int(1e6),progress_bar=True)
env.close()
# Out:
# Using cpu device
# Logging to ./PPOLunar_tensorboard/PPO_1
# Output()
# -----------------------------
# | time/              |      |
# |    fps             | 279  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 1024 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0028168964 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.000943     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.69e+03     |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00518     |
# |    value_loss           | 6.48e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 360           |
# |    iterations           | 3             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 0.00097297446 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.0155        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.24e+03      |
# |    n_updates            | 8             |
# |    policy_gradient_loss | -0.00197      |
# |    value_loss           | 2.26e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 397           |
# |    iterations           | 4             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00014040229 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.0311        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.01e+03      |
# |    n_updates            | 12            |
# |    policy_gradient_loss | -0.00117      |
# |    value_loss           | 4.21e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 421           |
# |    iterations           | 5             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 0.00018972548 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00989      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.89e+03      |
# |    n_updates            | 16            |
# |    policy_gradient_loss | -0.000897     |
# |    value_loss           | 5.22e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 430          |
# |    iterations           | 6            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 3.830809e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0413      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.3e+03      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000443    |
# |    value_loss           | 4.77e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 424           |
# |    iterations           | 7             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 0.00039387343 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00494      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.27e+03      |
# |    n_updates            | 24            |
# |    policy_gradient_loss | -0.00168      |
# |    value_loss           | 5.49e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 427           |
# |    iterations           | 8             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00027001975 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.0284       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.42e+03      |
# |    n_updates            | 28            |
# |    policy_gradient_loss | -0.00141      |
# |    value_loss           | 5.37e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 431           |
# |    iterations           | 9             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 0.00030115806 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00251      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 507           |
# |    n_updates            | 32            |
# |    policy_gradient_loss | -0.000779     |
# |    value_loss           | 1.26e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 10           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0006518823 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00505     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.23e+03     |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 3.89e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 442           |
# |    iterations           | 11            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 0.00029813038 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00308      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.44e+03      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00149      |
# |    value_loss           | 5.63e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 451           |
# |    iterations           | 12            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00087598216 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.000191      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.59e+03      |
# |    n_updates            | 44            |
# |    policy_gradient_loss | -0.00173      |
# |    value_loss           | 3.24e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 460           |
# |    iterations           | 13            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 0.00094010396 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00229      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.45e+03      |
# |    n_updates            | 48            |
# |    policy_gradient_loss | -0.00244      |
# |    value_loss           | 3.42e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 14           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0023128726 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00298     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09e+03     |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00336     |
# |    value_loss           | 2.11e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 472          |
# |    iterations           | 15           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0042145276 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00156     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 832          |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00473     |
# |    value_loss           | 1.64e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 16           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0017143788 |
# |    clip_fraction        | 0.00562      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0659       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 276          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 693          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 461          |
# |    iterations           | 17           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0025728024 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.0588       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 571          |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 1.42e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 463           |
# |    iterations           | 18            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00086383324 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | -0.00438      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.39e+03      |
# |    n_updates            | 68            |
# |    policy_gradient_loss | -0.00193      |
# |    value_loss           | 2.71e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 19           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0007146955 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.0449      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+03     |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 2.62e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 20          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.000616005 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.00782    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 607         |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.000683   |
# |    value_loss           | 1.21e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 21          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.004115738 |
# |    clip_fraction        | 0.000488    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.0018     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 493         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00369    |
# |    value_loss           | 1.35e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 22           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0016049662 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.00689     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.75e+03     |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.0038      |
# |    value_loss           | 3.35e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 474          |
# |    iterations           | 23           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0016413411 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.00201     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12e+03     |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 2.34e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 24           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0004118813 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.013       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.1e+03      |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 2.63e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 479          |
# |    iterations           | 25           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0012864762 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.00106     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.01e+03     |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 3.64e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 26           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0014721307 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.00063     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 718          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 1.24e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 484          |
# |    iterations           | 27           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 0.0020668546 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.00635     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76e+03     |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.00392     |
# |    value_loss           | 3.4e+03      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 487           |
# |    iterations           | 28            |
# |    time_elapsed         | 58            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00087776274 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | -0.000245     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 664           |
# |    n_updates            | 108           |
# |    policy_gradient_loss | -0.00139      |
# |    value_loss           | 1.67e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 489          |
# |    iterations           | 29           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0001769439 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.00404     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.99e+03     |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00058     |
# |    value_loss           | 3.28e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 491          |
# |    iterations           | 30           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0009919186 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.016       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 625          |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00246     |
# |    value_loss           | 1.17e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 493           |
# |    iterations           | 31            |
# |    time_elapsed         | 64            |
# |    total_timesteps      | 31744         |
# | train/                  |               |
# |    approx_kl            | 0.00086937833 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.32         |
# |    explained_variance   | -0.00144      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 523           |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00167      |
# |    value_loss           | 1.54e+03      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 32          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006837004 |
# |    clip_fraction        | 0.00415     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00162    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 442         |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.00509    |
# |    value_loss           | 887         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 33          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.007174899 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.0149      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 283         |
# |    n_updates            | 128         |
# |    policy_gradient_loss | -0.00898    |
# |    value_loss           | 519         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 34          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.002372322 |
# |    clip_fraction        | 0.00317     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0908      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 487         |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 960         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 499          |
# |    iterations           | 35           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0008876128 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -0.033       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 660          |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 1.27e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 500          |
# |    iterations           | 36           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0045150416 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | -0.00836     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 816          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00464     |
# |    value_loss           | 1.3e+03      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 501        |
# |    iterations           | 37         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 37888      |
# | train/                  |            |
# |    approx_kl            | 0.00798503 |
# |    clip_fraction        | 0.0176     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | -0.000872  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 333        |
# |    n_updates            | 144        |
# |    policy_gradient_loss | -0.00525   |
# |    value_loss           | 651        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 502         |
# |    iterations           | 38          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009375268 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.0184     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 322         |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.00984    |
# |    value_loss           | 713         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 504          |
# |    iterations           | 39           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0048633786 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | -0.00136     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 202          |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 387          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 505          |
# |    iterations           | 40           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0023466726 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -0.000269    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 368          |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.000755    |
# |    value_loss           | 610          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 507         |
# |    iterations           | 41          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.005026526 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.000875   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 264         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00634    |
# |    value_loss           | 641         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 42          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004386936 |
# |    clip_fraction        | 0.0137      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -0.000391   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 287         |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.00136    |
# |    value_loss           | 570         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 510          |
# |    iterations           | 43           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0068558306 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | -0.000165    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 274          |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.00625     |
# |    value_loss           | 467          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 511         |
# |    iterations           | 44          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010381363 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | -0.000203   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 442         |
# |    n_updates            | 172         |
# |    policy_gradient_loss | -0.00821    |
# |    value_loss           | 1e+03       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 512         |
# |    iterations           | 45          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.001094801 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -0.0031     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 324         |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.000183   |
# |    value_loss           | 639         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 513          |
# |    iterations           | 46           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0013750456 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -2.07e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 408          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00302     |
# |    value_loss           | 868          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 514         |
# |    iterations           | 47          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.007115202 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | -0.000228   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 230         |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.00049    |
# |    value_loss           | 500         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 515           |
# |    iterations           | 48            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00014576543 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.17         |
# |    explained_variance   | -0.000419     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 290           |
# |    n_updates            | 188           |
# |    policy_gradient_loss | -0.00045      |
# |    value_loss           | 712           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 49           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0004782951 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.00117      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 316          |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 657          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 50           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0102488715 |
# |    clip_fraction        | 0.0884       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.0273       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 124          |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.00715     |
# |    value_loss           | 216          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 51           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 52224        |
# | train/                  |              |
# |    approx_kl            | 0.0003084154 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | -0.00231     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 248          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000726    |
# |    value_loss           | 562          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 515           |
# |    iterations           | 52            |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00023531046 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.19         |
# |    explained_variance   | 0.0146        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 297           |
# |    n_updates            | 204           |
# |    policy_gradient_loss | -0.0012       |
# |    value_loss           | 468           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 515         |
# |    iterations           | 53          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 54272       |
# | train/                  |             |
# |    approx_kl            | 0.001349069 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.0929      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 152         |
# |    n_updates            | 208         |
# |    policy_gradient_loss | -0.00143    |
# |    value_loss           | 203         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 54          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.003278438 |
# |    clip_fraction        | 0.00146     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.0116      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 167         |
# |    n_updates            | 212         |
# |    policy_gradient_loss | -0.000874   |
# |    value_loss           | 272         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 512          |
# |    iterations           | 55           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 56320        |
# | train/                  |              |
# |    approx_kl            | 4.009559e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0724      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.11e+03     |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -1.86e-05    |
# |    value_loss           | 2.21e+03     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 513        |
# |    iterations           | 56         |
# |    time_elapsed         | 111        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.00413274 |
# |    clip_fraction        | 0.0151     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | 0.0623     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 472        |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00388   |
# |    value_loss           | 650        |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 57           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 58368        |
# | train/                  |              |
# |    approx_kl            | 0.0003255679 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.013        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 408          |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.000981    |
# |    value_loss           | 555          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 514           |
# |    iterations           | 58            |
# |    time_elapsed         | 115           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00017197162 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | 0.00759       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 204           |
# |    n_updates            | 228           |
# |    policy_gradient_loss | -0.000379     |
# |    value_loss           | 427           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 514           |
# |    iterations           | 59            |
# |    time_elapsed         | 117           |
# |    total_timesteps      | 60416         |
# | train/                  |               |
# |    approx_kl            | 0.00048696646 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.22         |
# |    explained_variance   | 0.0018        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 301           |
# |    n_updates            | 232           |
# |    policy_gradient_loss | -0.00109      |
# |    value_loss           | 735           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 60           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0044290703 |
# |    clip_fraction        | 0.00635      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.0313       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 149          |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -0.00371     |
# |    value_loss           | 332          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 516           |
# |    iterations           | 61            |
# |    time_elapsed         | 120           |
# |    total_timesteps      | 62464         |
# | train/                  |               |
# |    approx_kl            | 0.00096961146 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.13         |
# |    explained_variance   | -0.00828      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 399           |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.00124      |
# |    value_loss           | 709           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 62           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0069632526 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.114        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.3         |
# |    n_updates            | 244          |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 223          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 517           |
# |    iterations           | 63            |
# |    time_elapsed         | 124           |
# |    total_timesteps      | 64512         |
# | train/                  |               |
# |    approx_kl            | 0.00014000002 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.26         |
# ...
# |    entropy_loss         | -0.702       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.72         |
# |    n_updates            | 3824         |
# |    policy_gradient_loss | -0.00322     |
# |    value_loss           | 6.64         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 958          |
# |    time_elapsed         | 1678         |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0027267386 |
# |    clip_fraction        | 0.00708      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.628       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.21         |
# |    n_updates            | 3828         |
# |    policy_gradient_loss | -0.00354     |
# |    value_loss           | 5.42         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 959          |
# |    time_elapsed         | 1679         |
# |    total_timesteps      | 982016       |
# | train/                  |              |
# |    approx_kl            | 0.0016989803 |
# |    clip_fraction        | 0.0388       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.669       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.85         |
# |    n_updates            | 3832         |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 8.26         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 960         |
# |    time_elapsed         | 1681        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.011675086 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.708      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32        |
# |    n_updates            | 3836        |
# |    policy_gradient_loss | -0.00279    |
# |    value_loss           | 5.13        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 961         |
# |    time_elapsed         | 1683        |
# |    total_timesteps      | 984064      |
# | train/                  |             |
# |    approx_kl            | 0.001255392 |
# |    clip_fraction        | 0.00122     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.703      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.41        |
# |    n_updates            | 3840        |
# |    policy_gradient_loss | 0.000675    |
# |    value_loss           | 7.75        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 962         |
# |    time_elapsed         | 1684        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.004086844 |
# |    clip_fraction        | 0.0249      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.697      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.814       |
# |    n_updates            | 3844        |
# |    policy_gradient_loss | -0.00112    |
# |    value_loss           | 3.31        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 963         |
# |    time_elapsed         | 1686        |
# |    total_timesteps      | 986112      |
# | train/                  |             |
# |    approx_kl            | 0.018115459 |
# |    clip_fraction        | 0.0557      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.631       |
# |    n_updates            | 3848        |
# |    policy_gradient_loss | -0.000313   |
# |    value_loss           | 3.69        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 964         |
# |    time_elapsed         | 1688        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.004160748 |
# |    clip_fraction        | 0.0732      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.663      |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.19        |
# |    n_updates            | 3852        |
# |    policy_gradient_loss | -0.00516    |
# |    value_loss           | 20.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 965          |
# |    time_elapsed         | 1689         |
# |    total_timesteps      | 988160       |
# | train/                  |              |
# |    approx_kl            | 0.0014416968 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.6         |
# |    n_updates            | 3856         |
# |    policy_gradient_loss | -0.000204    |
# |    value_loss           | 54.3         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 584           |
# |    iterations           | 966           |
# |    time_elapsed         | 1691          |
# |    total_timesteps      | 989184        |
# | train/                  |               |
# |    approx_kl            | 0.00011339475 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.757        |
# |    explained_variance   | 0.746         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 395           |
# |    n_updates            | 3860          |
# |    policy_gradient_loss | -0.000384     |
# |    value_loss           | 839           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 967         |
# |    time_elapsed         | 1693        |
# |    total_timesteps      | 990208      |
# | train/                  |             |
# |    approx_kl            | 0.004229282 |
# |    clip_fraction        | 0.00732     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.3        |
# |    n_updates            | 3864        |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 39.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 968         |
# |    time_elapsed         | 1694        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.003359359 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.6        |
# |    n_updates            | 3868        |
# |    policy_gradient_loss | 0.000519    |
# |    value_loss           | 44.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 969         |
# |    time_elapsed         | 1696        |
# |    total_timesteps      | 992256      |
# | train/                  |             |
# |    approx_kl            | 0.005577271 |
# |    clip_fraction        | 0.0371      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.543      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.806       |
# |    n_updates            | 3872        |
# |    policy_gradient_loss | -0.000281   |
# |    value_loss           | 3.62        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 970         |
# |    time_elapsed         | 1698        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.004602742 |
# |    clip_fraction        | 0.0413      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.1        |
# |    n_updates            | 3876        |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 128         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 971          |
# |    time_elapsed         | 1699         |
# |    total_timesteps      | 994304       |
# | train/                  |              |
# |    approx_kl            | 0.0002495433 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.673       |
# |    explained_variance   | 0.791        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 112          |
# |    n_updates            | 3880         |
# |    policy_gradient_loss | -8.2e-05     |
# |    value_loss           | 325          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 972          |
# |    time_elapsed         | 1701         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0006883679 |
# |    clip_fraction        | 0.000732     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.8         |
# |    n_updates            | 3884         |
# |    policy_gradient_loss | -0.000643    |
# |    value_loss           | 39.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 973          |
# |    time_elapsed         | 1702         |
# |    total_timesteps      | 996352       |
# | train/                  |              |
# |    approx_kl            | 0.0041839625 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.67        |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.7         |
# |    n_updates            | 3888         |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 60           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 974          |
# |    time_elapsed         | 1704         |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0009846188 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.667       |
# |    explained_variance   | 0.977        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.48         |
# |    n_updates            | 3892         |
# |    policy_gradient_loss | -0.000944    |
# |    value_loss           | 48           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 975          |
# |    time_elapsed         | 1706         |
# |    total_timesteps      | 998400       |
# | train/                  |              |
# |    approx_kl            | 0.0017010202 |
# |    clip_fraction        | 0.00244      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.7         |
# |    explained_variance   | 0.698        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 882          |
# |    n_updates            | 3896         |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 827          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 976          |
# |    time_elapsed         | 1707         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0019609972 |
# |    clip_fraction        | 0.00684      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.663       |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.63         |
# |    n_updates            | 3900         |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 32.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 977          |
# |    time_elapsed         | 1709         |
# |    total_timesteps      | 1000448      |
# | train/                  |              |
# |    approx_kl            | 0.0035923827 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.735       |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.2         |
# |    n_updates            | 3904         |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 23.4         |
# ------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ## 5- Evaluation du model

# %%
eval_env = Monitor(gym.make("LunarLander-v2",render_mode="human"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True,render=True)
eval_env.close()
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=263.65 +/- 12.86028496538323

# %% [markdown]
# ## 6- Enregistrer le modele

# %%
model.save("model_lunar")
del model

# %% [markdown]
# ## 7- Resultat

# %%
model=PPO.load("model_lunar",env=Monitor(gym.make("LunarLander-v2",render_mode="human")), tensorboard_log="./ppo_tensorboard/")
vec_env = model.get_env()
# Out:
# Wrapping the env in a DummyVecEnv.

# %%
for episode in range (1,11):
    obs = vec_env.reset()
    done=False
    score=0
    while not done:
        action, states = model.predict(obs, deterministic=True)
        obs, reward, done, info = vec_env.step(action)
        vec_env.render()
        score += reward;
    print("Episode : {} ,Score : {}".format(episode,score))
vec_env.close()
# Out:
# Episode : 1 ,Score : [284.29962]
# Episode : 2 ,Score : [274.9049]
# Episode : 3 ,Score : [259.3791]
# Episode : 4 ,Score : [287.54697]
# Episode : 5 ,Score : [265.3504]
# Episode : 6 ,Score : [254.11987]
# Episode : 7 ,Score : [249.16115]
# Episode : 8 ,Score : [289.84793]
# Episode : 9 ,Score : [260.9319]
# Episode : 10 ,Score : [251.52075]

# %% [markdown]
# ## 8- Les graphes

# %% [markdown]
# python -m tensorboard.main --logdir ./PPOLunar_tensorboard/
